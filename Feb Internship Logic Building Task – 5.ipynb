# %% [markdown]
# # Problem 1: Social Media – Post Engagement Analyzer

# %%
def engagement_post(likes_list):
    T_likes = 0
    
    for like in likes_list:
        T_likes += like

    if T_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    print("Total Likes:", T_likes)
    print("Post Status:", status)

engagement_post([100, 300, 250, 300])
# Out:
# Total Likes: 950
# Post Status: Normal Engagement

# %% [markdown]
# # Problem 2: Healthcare – Medicine Stock Alert System

# %%
def medicine_stock(stock):
    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"

    print("Medicine Stock:", stock)
    print("Status:", status)
stock_input = int(input("Enter medical stock: "))
medicine_stock(stock_input)
# Out:
# Enter medical stock:  4
# Medicine Stock: 4
# Status: Low Stock Alert

# %% [markdown]
# # Problem 3: Agriculture – Rainfall Adequacy Checker

# %%
def rainfall_checker(rainfall_data, required_level):
    total = 0

    for rain in rainfall_data:
        total += rain

    average = total / len(rainfall_data)

    if average >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"

    print("Average Rainfall:", average)
    print("Rainfall Status:", status)
rainfall_checker([70, 75, 80, 65], 70)
# Out:
# Average Rainfall: 72.5
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# # Problem 4: Social Media – Duplicate Account Detection

# %%
def detect_duplicates(usernames):
    seen = set()
    duplicates = set()

    for user in usernames:
        if user in seen:
            duplicates.add(user)
        else:
            seen.add(user)

    if duplicates:
        print("Duplicate Accounts Found: Yes")
        print("Duplicate Usernames:", list(duplicates))
    else:
        print("Duplicate Accounts Found: No")

detect_duplicates(["soniya", "neeraj", "soniya", "sinchana", "neeraj"])
# Out:
# Duplicate Accounts Found: Yes
# Duplicate Usernames: ['soniya', 'neeraj']

# %% [markdown]
# # Problem 5: Healthcare – Appointment Eligibility Checker

# %%
def check_appointment_eligibility(age):
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print("Patient Age:", age)
    print("Eligibility Status:", status)
age_input= int(input("enter age: "))
check_appointment_eligibility(age_input)
# Out:
# enter age:  43
# Patient Age: 43
# Eligibility Status: Eligible

# %% [markdown]
# # Problem 6: Agriculture – Premium Crop Price Filter

# %%
def premium_crops(prices):
    premium = []

    for price in prices:
        if price > 2000:
            premium.append(price)

    print("Premium Crops:", premium)
premium_crops([1500, 2500, 1800, 3200])
# Out:
# Premium Crops: [2500, 3200]

# %% [markdown]
# # Problem 7: System Monitoring – Application Health Checker

# %%
def check_system_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    print("Error Count:", errors)
    print("System Status:", status)
error_count=int(input("Error count: "))
check_system_health(error_count)
# Out:
# Error count:  6
# Error Count: 6
# System Status: Critical Issues

# %% [markdown]
# # Problem 8: Banking – Daily Transaction Limit Checker

# %%
def transaction_checker(amount):
    daily_limit = 50000

    if amount <= daily_limit:
        status = "Approved"
    else:
        status = "Rejected"

    print("Transaction Amount:", amount)
    print("Transaction Status:", status)
transaction_checker(60000)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# # Problem 9: E-Learning – Student Attendance Eligibility System

# %%
def attendance_checker(attendance_list):
    total_classes = len(attendance_list)
    attended = 0

    for status in attendance_list:
        if status == "Present":
            attended += 1

    percentage = (attended / total_classes) * 100

    if percentage >= 75:
        eligibility = "Eligible"
    else:
        eligibility = "Not Eligible"

    print("Attendance Percentage:", percentage)
    print("Exam Eligibility:", eligibility)
attendance_checker(["Present", "Present", "Absent", "Present", "Present"])
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# # Problem 10: Smart Electricity Bill Analyzer

# %%
def electricity_bill(units):
    if units <= 100:
        bill = units * 3
    elif units <= 200:
        bill = (100 * 3) + (units - 100) * 5
    else:
        bill = (100 * 3) + (100 * 5) + (units - 200) * 7

    if bill < 500:
        usage = "Low Usage"
    elif bill <= 1500:
        usage = "Moderate Usage"
    else:
        usage = "High Usage"

    return bill, usage
bill_amount, usage_status = electricity_bill(250)
print("Total Bill:", bill_amount)
print("Usage Classification:", usage_status)
# Out:
# Total Bill: 1150
# Usage Classification: Moderate Usage
